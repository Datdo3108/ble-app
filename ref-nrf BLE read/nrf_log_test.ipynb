# %%
import ctypes

# Load the J-Link DLL
jlink_dll = ctypes.CDLL("C:/Program Files/SEGGER/JLink_V798i/JLink_x64.dll")  # Adjust path

# List all available functions in the DLL
print(dir(jlink_dll))
# Out:
# ['_FuncPtr', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_func_flags_', '_func_restype_', '_handle', '_name']

# %%
import ctypes
import time

# Load the J-Link RTT DLL using the full path
jlink_dll = ctypes.CDLL("C:/Program Files/SEGGER/JLink_V798i/JLink_x64.dll")  # Adjust the path

# %%
# Connect to the J-Link device
jlink_dll.JLINKARM_Open()

# Specify the target device (e.g., nRF52)
jlink_dll.JLINKARM_ExecCommand(b"Device = NRF52", None, 0)
# Out:
# 0

# %%
import ctypes

# Load the J-Link DLL
jlink_dll = ctypes.CDLL("C:/Program Files/SEGGER/JLink_V798i/JLink_x64.dll")  # Adjust path

# List all available functions in the DLL
functions = dir(jlink_dll)
print("Available functions in JLink DLL:")
for func in functions:
        print(func)
# Out:
# Available functions in JLink DLL:
# _FuncPtr
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattr__
# __getattribute__
# __getitem__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# _func_flags_
# _func_restype_
# _handle
# _name

# %%
import subprocess
import time

# Path to the JLinkRTTViewer executable
jlink_rtt_viewer_path = "C:/Program Files/SEGGER/JLink_V798i/JLinkRTTViewer.exe"  # Adjust the path

# Launch the JLinkRTTViewer
process = subprocess.Popen([jlink_rtt_viewer_path])

# Optionally, you can wait for a few seconds to let the viewer open
time.sleep(5)

# You can perform other actions while the viewer is running...

# Wait for the user to close the viewer
process.wait()
# Out:
# 0

# %%
import pyautogui
pyautogui.displayMousePosition()
# Out:
# Press Ctrl-C to quit.
# ...

# %%
import subprocess
import time
import pyautogui

# Path to the JLinkRTTViewer executable
jlink_rtt_viewer_path = "C:/Program Files/SEGGER/JLink_V798i/JLinkRTTViewer.exe"  # Adjust the path

# Launch the JLinkRTTViewer
process = subprocess.Popen([jlink_rtt_viewer_path])

# Give it time to open
time.sleep(5)

# Step 1: Click the "Connect" button
# Adjust coordinates according to your screen resolution and button location
pyautogui.moveTo(100, 200)  # Adjust the coordinates of the "Connect" button
pyautogui.click()

# Step 2: Wait for the connection to be established (adjust the wait time as needed)
time.sleep(5)

# Step 3: Start data logging (adjust coordinates to the "Start Logging" button)
pyautogui.moveTo(150, 250)  # Adjust the coordinates of the "Start Logging" button
pyautogui.click()

# Step 4: Enter the file name for saving the log
# Wait for the save dialog to open (you may need to adjust the time)
time.sleep(2)
pyautogui.typewrite("my_log_file.txt")  # Type the file name you want
pyautogui.press("enter")  # Confirm the file name entry

# Step 5: Wait for the logging to proceed for some time
time.sleep(10)  # Adjust this based on how long you want to log data

# Optional: Automate stopping the logging or other actions
# For example, clicking a "Stop Logging" button if it exists
# pyautogui.moveTo(stop_button_x, stop_button_y)  # Adjust coordinates
# pyautogui.click()

# Wait for the user to close the viewer or process to finish
process.wait()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 33
#      30 pyautogui.press("enter")  # Confirm the file name entry
#      32 # Step 5: Wait for the logging to proceed for some time
# ---> 33 time.sleep(10)  # Adjust this based on how long you want to log data
#      35 # Optional: Automate stopping the logging or other actions
#      36 # For example, clicking a "Stop Logging" button if it exists
#      37 # pyautogui.moveTo(stop_button_x, stop_button_y)  # Adjust coordinates
#      38 # pyautogui.click()
#      39
#      40 # Wait for the user to close the viewer or process to finish
#      41 process.wait()
#
# KeyboardInterrupt:

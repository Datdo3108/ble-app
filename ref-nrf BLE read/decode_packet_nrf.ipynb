# %%
# import struct

# Your data packet as a byte string
# data = b'\xc0\x00\x00\xfa:j\xe67\x14\xe2B\xd0\xef\xc6\x05\x9b'
data = b'\xc0\x00\x00\xff\xd1.\xffN\x17\xff\xf1\xc1\xffs\x13k'

# Example 1: Convert to a list of integers
integer_list = list(data)
print("Integer list:", integer_list)
# Out:
# The file 'venv\lib\site-packages\prompt_toolkit\filters\__init__.py' seems to be overriding built in modules and interfering with the startup of the kernel. Consider renaming the file and starting the kernel again.
#
# Click <a href='https://aka.ms/kernelFailuresOverridingBuiltInModules'>here</a> for more info.

# %%
d = int.from_bytes(data[3:6], byteorder='little')
print(d)
# Out:
# 6961914

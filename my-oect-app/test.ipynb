# %%
val = 1010
print(bytes[val])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 val = 1010
# ----> 2 print(bytes[val])
#
# TypeError: type 'bytes' is not subscriptable
